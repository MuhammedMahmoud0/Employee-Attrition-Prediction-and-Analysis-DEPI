# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv("../../data/train.csv")
df.sample(5)
# Out:
#        Unnamed: 0  employee_id  age  gender  years_at_company    job_role  \
# 5542         5542        30022   22  Female                 6  Technology
# 45712       45712        42757   42    Male                 1  Technology
# 20808       20808        20997   19  Female                 1       Media
# 37648       37648        13188   56  Female                42       Media
# 37686       37686        47161   50  Female                 3  Healthcare
#
#        monthly_income work-life_balance job_satisfaction performance_rating  \
# 5542             7933         Excellent             High               High
# 45712            8261              Good        Very High               High
# 20808            6715              Fair           Medium            Average
# 37648            5513         Excellent             High            Average
# 37686            8839              Fair        Very High               High
#
#        ...  number_of_dependents job_level  company_size company_tenure  \
# 5542   ...                     1     Entry         Small             31
# 45712  ...                     4       Mid        Medium             25
# 20808  ...                     4       Mid         Small             37
# 37648  ...                     5     Entry        Medium            106
# 37686  ...                     2     Entry         Small             23
#
#       remote_work  leadership_opportunities innovation_opportunities  \
# 5542           No                        No                       No
# 45712          No                        No                      Yes
# 20808          No                        No                       No
# 37648          No                        No                       No
# 37686          No                        No                       No
#
#       company_reputation  employee_recognition attrition
# 5542                Fair                   Low      Left
# 45712               Good                   Low      Left
# 20808               Poor                   Low    Stayed
# 37648          Excellent                  High    Stayed
# 37686               Good                  High      Left
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                59598 non-null  int64
#  1   employee_id               59598 non-null  int64
#  2   age                       59598 non-null  int64
#  3   gender                    59598 non-null  object
#  4   years_at_company          59598 non-null  int64
#  5   job_role                  59598 non-null  object
#  6   monthly_income            59598 non-null  int64
#  7   work-life_balance         59598 non-null  object
#  8   job_satisfaction          59598 non-null  object
#  9   performance_rating        59598 non-null  object
#  10  number_of_promotions      59598 non-null  int64
#  11  overtime                  59598 non-null  object
#  12  distance_from_home        59598 non-null  int64
#  13  education_level           59598 non-null  object
#  14  marital_status            59598 non-null  object
#  15  number_of_dependents      59598 non-null  int64
#  16  job_level                 59598 non-null  object
#  17  company_size              59598 non-null  object
#  18  company_tenure            59598 non-null  int64
#  19  remote_work               59598 non-null  object
#  20  leadership_opportunities  59598 non-null  object
#  21  innovation_opportunities  59598 non-null  object
#  22  company_reputation        59598 non-null  object
#  23  employee_recognition      59598 non-null  object
#  24  attrition                 59598 non-null  object
# dtypes: int64(9), object(16)
# memory usage: 11.4+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0   employee_id           age  years_at_company  \
# count  59598.000000  59598.000000  59598.000000      59598.000000
# mean   29798.500000  37227.118729     38.565875         15.753901
# std    17204.605009  21519.150028     12.079673         11.245981
# min        0.000000      1.000000     18.000000          1.000000
# 25%    14899.250000  18580.250000     28.000000          7.000000
# 50%    29798.500000  37209.500000     39.000000         13.000000
# 75%    44697.750000  55876.750000     49.000000         23.000000
# max    59597.000000  74498.000000     59.000000         51.000000
#
#        monthly_income  number_of_promotions  distance_from_home  \
# count    59598.000000          59598.000000        59598.000000
# mean      7302.397983              0.832578           50.007651
# std       2151.457423              0.994991           28.466459
# min       1316.000000              0.000000            1.000000
# 25%       5658.000000              0.000000           25.000000
# 50%       7354.000000              1.000000           50.000000
# 75%       8880.000000              2.000000           75.000000
# max      16149.000000              4.000000           99.000000
#
#        number_of_dependents  company_tenure
# count          59598.000000    59598.000000
# mean               1.648075       55.758415
# std                1.555689       25.411090
# min                0.000000        2.000000
# 25%                0.000000       36.000000
# 50%                1.000000       56.000000
# 75%                3.000000       76.000000
# max                6.000000      128.000000

# %%
df.describe(include="object")
# Out:
#        gender    job_role work-life_balance job_satisfaction  \
# count   59598       59598             59598            59598
# unique      2           5                 4                4
# top      Male  Technology              Good             High
# freq    32739       15507             22528            29779
#
#        performance_rating overtime    education_level marital_status  \
# count               59598    59598              59598          59598
# unique                  4        2                  5              3
# top               Average       No  Bachelor’s Degree        Married
# freq                35810    40148              17826          29908
#
#        job_level company_size remote_work leadership_opportunities  \
# count      59598        59598       59598                    59598
# unique         3            3           2                        2
# top        Entry       Medium          No                       No
# freq       23867        29745       48239                    56680
#
#        innovation_opportunities company_reputation employee_recognition  \
# count                     59598              59598                59598
# unique                        2                  4                    4
# top                          No               Good                  Low
# freq                      49895              29766                23758
#
#        attrition
# count      59598
# unique         2
# top       Stayed
# freq       31260

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# employee_id                 0
# age                         0
# gender                      0
# years_at_company            0
# job_role                    0
# monthly_income              0
# work-life_balance           0
# job_satisfaction            0
# performance_rating          0
# number_of_promotions        0
# overtime                    0
# distance_from_home          0
# education_level             0
# marital_status              0
# number_of_dependents        0
# job_level                   0
# company_size                0
# company_tenure              0
# remote_work                 0
# leadership_opportunities    0
# innovation_opportunities    0
# company_reputation          0
# employee_recognition        0
# attrition                   0
# dtype: int64

# %%
df.select_dtypes(include="object").isin(["None",""," ","NA","Null","none"]).sum()
# Out:
# gender                      0
# job_role                    0
# work-life_balance           0
# job_satisfaction            0
# performance_rating          0
# overtime                    0
# education_level             0
# marital_status              0
# job_level                   0
# company_size                0
# remote_work                 0
# leadership_opportunities    0
# innovation_opportunities    0
# company_reputation          0
# employee_recognition        0
# attrition                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()

# %%
df.to_csv("../../data/Cleaned_Data/train_cleaned.csv",index=False)
